# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
data0 = [2, 4, 6.5, 8]
arr0 = np.array(data0)

# %%
#任务1：将列表转化为Numpy数组
data0=[2,4,6.5,8]
arr0=np.array(data0)

# %%
#任务2：新建Pandas中的Series 数据类型，打印出大小、索引值

# %%
#pandas中的series数据类型
s = pd.Series([100,'a',{'dic1':5}], index=pd.Index(['id1',20,'third'],name='my_idx'),
              dtype='object',
              name='my_name')

# %%
s2=pd.Series(['1','2','3','4'])

# %%
s2.index.values
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
type(s2.values[0])
# Out:
# str

# %%
s2.size
# Out:
# 4

# %%
s2.shape
# Out:
# (4,)

# %%
#任务3：创建DataFrame类型的数据，并获取其索引、值及大小
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),
}
df = pd.DataFrame(d)

# %%
d1 = {
    "作者": pd.Series(["余华", "路遥", "莫言"]),
    "书名": pd.Series(["活着","平凡的世界", "红高粱"]),
    "售价": pd.Series([30,34,50])
}
df2 = pd.DataFrame(d1)

# %%
df2[['作者','售价']]
# Out:
#    作者  售价
# 0  余华  30
# 1  路遥  34
# 2  莫言  50

# %%
df2.values
# Out:
# array([['余华', '活着', 30],
#        ['路遥', '平凡的世界', 34],
#        ['莫言', '红高粱', 50]], dtype=object)

# %%
贵州茅台原始数据=pd.read_csv(R'600519.csv')

# %%
#按列查询数据
贵州茅台原始数据['TURNOVER']
# Out:
# 0        1410347008
# 1         463463008
# 2         194689000
# 3         177558000
# 4          86231000
#            ...
# 4089     2694714080
# 4090    10663392512
# 4091     5239853056
# 4092     5581027328
# 4093     5227695104
# Name: TURNOVER, Length: 4094, dtype: int64

# %%
贵州茅台原始数据[['TURNOVER','volume']]
# Out:
#          TURNOVER  volume
# 0      1410347008  406318
# 1       463463008  129647
# 2       194689000   53252
# 3       177558000   48013
# 4        86231000   23231
# ...           ...     ...
# 4089   2694714080   49076
# 4090  10663392512  204397
# 4091   5239853056   96885
# 4092   5581027328   98107
# 4093   5227695104   89157
#
# [4094 rows x 2 columns]

# %%
#按行索引
贵州茅台原始数据.loc[0]
# Out:
# day           2001-08-27
# STOCK_CODE       6005191
# open               34.51
# close              35.55
# maximum            37.78
# minimum            32.85
# volume            406318
# TURNOVER      1410347008
# Name: 0, dtype: object

# %%
贵州茅台=贵州茅台原始数据.set_index('day')

# %%
#loc索引器
#单个元素
贵州茅台.loc['2001-08-27']
# Out:
# STOCK_CODE    6.005191e+06
# open          3.451000e+01
# close         3.555000e+01
# maximum       3.778000e+01
# minimum       3.285000e+01
# volume        4.063180e+05
# TURNOVER      1.410347e+09
# Name: 2001-08-27, dtype: float64

# 2001-11-08     6005191  33.35  33.70    33.89    32.98    7402   24682000
# ...                ...    ...    ...      ...      ...     ...        ...
# 2004-09-21     6005191  32.09  32.30    32.98    32.09    8374   27222818
# 2004-09-22     6005191  32.03  32.16    32.49    32.03    4348   13965168
# 2004-09-23     6005191  32.11  33.42    33.52    32.11   17667   58219692
# 2004-09-24     6005191  33.60  34.49    35.89    33.60   30981  108295826
# 2004-09-27     6005191  34.95  34.93    35.98    34.50    6067   21339456
#
# [498 rows x 7 columns]

# %%
#使用函数作为索引
def condition(pd):
    c1 = pd['open']<35
    c2 =pd['close']<35
    布尔列表=c1&c2
    return 布尔列表

# %%
贵州茅台.loc[condition]
# Out:
#             STOCK_CODE   open  close  maximum  minimum  volume   TURNOVER
# day
# 2001-10-17     6005191  34.79  34.20    34.81    33.90   12507   42766000
# 2001-10-18     6005191  34.20  34.04    34.66    33.91    4983   16999000
# 2001-10-19     6005191  34.00  33.50    34.15    33.01   15687   52422000
# 2001-10-22     6005191  33.30  32.79    33.70    32.70    9760   32268000
# 2001-11-08     6005191  33.35  33.70    33.89    32.98    7402   24682000
# ...                ...    ...    ...      ...      ...     ...        ...
# 2004-09-21     6005191  32.09  32.30    32.98    32.09    8374   27222818
# 2004-09-22     6005191  32.03  32.16    32.49    32.03    4348   13965168
# 2004-09-23     6005191  32.11  33.42    33.52    32.11   17667   58219692
# 2004-09-24     6005191  33.60  34.49    35.89    33.60   30981  108295826
# 2004-09-27     6005191  34.95  34.93    35.98    34.50    6067   21339456
#
# [498 rows x 7 columns]

# %%
贵州茅台.query('open<35 and close<35')[['open','close']]
# Out:
#              open  close
# day
# 2001-10-17  34.79  34.20
# 2001-10-18  34.20  34.04
# 2001-10-19  34.00  33.50
# 2001-10-22  33.30  32.79
# 2001-11-08  33.35  33.70
# ...           ...    ...
# 2004-09-21  32.09  32.30
# 2004-09-22  32.03  32.16
# 2004-09-23  32.11  33.42
# 2004-09-24  33.60  34.49
# 2004-09-27  34.95  34.93
#
# [498 rows x 2 columns]

# %%
贵州茅台.sample(10)
# Out:
#             STOCK_CODE    open   close  maximum  minimum  volume    TURNOVER
# day
# 2010-02-22     6005191  173.00  169.08   173.10   169.07   12178   207127846
# 2007-01-19     6005191  105.22  109.35   111.89   105.22   22256   243504208
# 2007-05-14     6005191   93.60   94.39   100.78    92.18  131870  1263779088
# 2006-06-05     6005191   46.60   44.87    46.60    43.80   68748   308294272
# 2014-04-17     6005191  170.80  175.20   176.00   170.21   29744   517914688
# 2018-09-14     6005191  633.98  642.90   649.78   628.53   40900  2617626832
# 2008-06-27     6005191  142.39  140.26   143.65   139.01   16260   228606779
# 2014-05-06     6005191  160.00  160.79   162.70   160.00   13623   219512505
# 2017-10-25     6005191  569.75  565.67   571.68   562.06   25076  1418395216
# 2003-09-16     6005191   21.10   21.12    21.30    20.82    1812     3803937

# %%
贵州茅台.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4094 entries, 2001-08-27 to 2018-11-02
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STOCK_CODE  4094 non-null   int64
#  1   open        4094 non-null   float64
#  2   close       4094 non-null   float64
#  3   maximum     4094 non-null   float64
#  4   minimum     4094 non-null   float64
#  5   volume      4094 non-null   int64
#  6   TURNOVER    4094 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 384.9+ KB

# %%
贵州茅台.describe()
# Out:
#        STOCK_CODE         open        close      maximum      minimum  \
# count      4094.0  4094.000000  4094.000000  4094.000000  4094.000000
# mean    6005191.0   182.161910   182.435230   184.879680   179.801353
# std           0.0   165.857882   165.994905   168.082099   163.752065
# min     6005191.0    20.900000    20.880000    21.000000    20.710000
# 25%     6005191.0    47.405000    47.482500    48.222500    46.705000
# 50%     6005191.0   159.930000   159.980000   161.910000   157.875000
# 75%     6005191.0   208.500000   209.457500   212.175000   205.945000
# max     6005191.0   800.000000   799.190000   803.500000   788.880000
#
#               volume      TURNOVER
# count    4094.000000  4.094000e+03
# mean    27092.525892  6.487986e+08
# std     24623.472099  9.550262e+08
# min       238.000000  1.421413e+06
# 25%     10186.750000  6.203505e+07
# 50%     22491.000000  3.727192e+08
# 75%     36759.500000  7.486596e+08
# max    406318.000000  1.066339e+10

# %%
result =贵州茅台['open'].unique()

# %%
result2 =贵州茅台['open'].nunique()

# %%
result3 =贵州茅台['open'].value_counts()

# %%
df = pd.DataFrame({
    "name": ["A", "B", "C", "B", "C", "A", "C"],
    "value": [1, 3, 7, 2, 4, 3, 1]
})
df.groupby("name")["value"].sum()
# Out:
# name
# A     4
# B     5
# C    12
# Name: value, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']#设置字体
plt.rcParams['figure.figsize']=(6.4,4.8)#设置大小，默认为英寸
plt.rcParams['axes.unicode_minus']=False#该语句解决图像中的“-”负号的乱码问题

# %%
x=[1,2,3,4]
y=[1,4,2,3]

# %%
fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x = np.linspace(-2, 2, 1000) 
y1 = np.sqrt(1-(abs(x)-1)**2) 
y2 = -3*np.sqrt(1-(abs(x)/2)**0.5) 
fig, ax = plt.subplots()
ax.fill_between(x, y1, color='red') 
ax.fill_between(x, y2, color='red')
ax.set_aspect('equal') 
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x = np.linspace(-2, 2, 1000) 
y1 = np.sqrt(1-(abs(x)-1)**2) 
y2 = -3*np.sqrt(1-(abs(x)/2)**0.5) 
fig, ax = plt.subplots()
ax.fill_between(x, y1, color='pink') 
ax.fill_between(x, y2, color='red')
ax.set_aspect('equal') 
plt.show()
