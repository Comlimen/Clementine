# %%
#导入各种需要的包
import pandas as pd
import mytools
from pyreadstat import pyreadstat
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
列名列表=['父亲工作','父亲职业重新编码','母亲工作','母亲职业重新编码']
data=pd.read_csv(R'类别变量练习数据.csv',encoding='GBK')

# %%
tau_y = mytools.goodmanKruska_tau_y(data,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# 0.16222663747195426

# %%
mytools.相关系数强弱判断(tau_y)
# Out:
# '极弱相关或无相关'

# %%
mytools.制作交叉表(data,'父亲职业重新编码','母亲职业重新编码')
# Out:
# 母亲职业重新编码  上市民企     个体   事业单位     公务员   国企      家庭主妇    无        民企       All
# 父亲职业重新编码
# 个体         0.0  0.500  0.000  0.1250  0.0  0.416667  0.0  0.166667  0.226415
# 事业单位       0.0  0.000  0.125  0.0625  0.0  0.000000  0.0  0.000000  0.037736
# 公务员        0.0  0.250  0.750  0.6875  0.0  0.000000  0.0  0.500000  0.415094
# 国企         0.0  0.125  0.000  0.0000  1.0  0.083333  1.0  0.166667  0.094340
# 家庭主妇       0.0  0.000  0.000  0.0625  0.0  0.166667  0.0  0.000000  0.056604
# 民企         1.0  0.125  0.125  0.0625  0.0  0.333333  0.0  0.166667  0.169811

# %%
def create_pie_chart(x, y):
 x= data['父亲职业重新编码'].value_counts().index
y = data['父亲职业重新编码'].value_counts(normalize=True) 
fig,ax1 = plt.subplots()
labels = data['父亲职业重新编码'].value_counts() .index
ax1.pie(y,autopct='%1.1f%%', labels=labels,textprops=dict(color="black" )) 
plt.show()

# %%
def create_pie_chart(x, y):
 x= data['母亲职业重新编码'].value_counts().index
y = data['母亲职业重新编码'].value_counts(normalize=True) 
fig,ax1 = plt.subplots()
labels = data['母亲职业重新编码'].value_counts() .index
ax1.pie(y,autopct='%1.1f%%', labels=labels,textprops=dict(color="black" )) 
plt.show()
